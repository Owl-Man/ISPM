# %% [markdown]
# # **Задание №9. Разработка пользовательских интерфейсов (прототипы интерфейса)**

# %% [markdown]
# ## **Введение**

# %% [markdown]
# Проектирование пользовательского интерфейса является важным этапом в разработке информационных систем, определяющим удобство использования продукта и удовлетворённость конечных пользователей. В контексте управления проектами создания информационных систем качественное проектирование интерфейса существенно снижает затраты на доработки и поддержку, минимизирует количество ошибок пользователей и повышает эффективность работы с системой.

# %% [markdown]
# **Качественное проектирование интерфейса позволяет:**
# - Снизить время обучения пользователей на 50-80%
# - Уменьшить количество ошибок пользователей на 60-90%
# - Повысить производительность работы с системой на 20-50%
# - Сократить затраты на техническую поддержку на 30-40%
# - Увеличить удовлетворённость пользователей и лояльность к продукту
#
# В данном задании вы разработаете визуальные прототипы интерфейса вашей информационной системы, которые станут основой для реализации пользовательского взаимодействия.

# %% [markdown]
# ## **Связь с предыдущими заданиями**

# %% [markdown]
# - **Задание №3 (UML-диаграммы)** — техническое проектирование архитектуры и логики системы
# - **Задание №6 (Требования к интерфейсу)** — текстовое описание функциональных требований к интерфейсу
# - **Задание №7 (Анализ аналогов интерфейса)** — критический анализ существующих решений
# - **Задание №9 (текущее)** — создание визуальных прототипов вашего собственного решения

# %% [markdown]
# ## **Формулировка задания**

# %% [markdown]
# На основе ранее разработанных требований к системе (Задание №6) и анализа интерфейсов аналогичных систем (Задание №7) создайте комплект визуальных прототипов пользовательского интерфейса вашей информационной системы.

# %% [markdown]
# ### **Необходимо выполнить:**

# %% [markdown]
# 1. **Разработать информационную архитектуру системы**:
#    - Создайте карту навигации (карту сайта / приложения / (Вашего решения))
#    - Определите структуру экранов/страниц
#    - Спроектируйте пользовательские пути (сценарии взаимодействия)
#    - Обоснуйте логику навигации
#
# 2. **Создать каркасные модели (низкодетализированные прототипы)**:
#    - Разработайте схематичные прототипы 3 и более основных экранов
#    - Отобразите расположение элементов без визуального оформления
#    - Покажите структуру информации и функциональные элементы
#    - Используйте инструменты: Figma, Balsamiq, Draw.io, Miro
#
# 3. **Разработать детальные макеты (высокодетализированные прототипы)**:
#    - Создайте визуальные макеты 1-3 основных экранов
#    - Примените цветовую схему, типографику, стилизацию элементов
#    - Обеспечьте соответствие современным паттернам проектирования
#    - Учтите принципы визуальной иерархии
#
# 4. **Создать интерактивный прототип (опционально)**:
#    - Разработайте кликабельный прототип основного пользовательского сценария
#    - Продемонстрируйте навигацию между экранами
#    - Покажите интерактивные элементы и переходы
#
# 5. **Адаптировать под различные типы интерфейсов**:
#    - Для графических интерфейсов: адаптивность под различные устройства
#    - Для консольных интерфейсов: структура команд и вывода
#
# 6. **Обосновать принятые проектные решения**:
#    - Объясните выбор цветовой схемы и визуального стиля
#    - Покажите соответствие принципам юзабилити (из Задания №7)
#    - Продемонстрируйте, как устранены проблемы аналогов

# %% [markdown]
# ## **Краткая теория и практическое руководство**

# %% [markdown]
# ### **1. Информационная архитектура**

# %% [markdown]
# #### **Источники:**

# %% [markdown]
# 1. **Розенфельд Л., Морвиль П.** "Информационная архитектура в Интернете" / Пер. с англ. - СПб.: Символ-Плюс, 2020. - 544 с.
#
# 2. **Гарретт Дж.** "Элементы опыта взаимодействия" / Пер. с англ. - М.: Символ, 2019. - 192 с.
#
# 3. **Купер А., Рейманн Р., Кронин Д.** "Интерфейс. Основы проектирования взаимодействия" - СПб.: Питер, 2021. - 720 с.

# %% [markdown]
# #### **Теоретическая часть:**

# %% [markdown]
# **Информационная архитектура** — это структурная организация контента и функциональности системы, обеспечивающая интуитивную навигацию и эффективный поиск информации.

# %% [markdown]
# ![Текст ссылки](https://i0.wp.com/cms-assets.tutsplus.com/cdn-cgi/image/width=850/uploads/users/30/posts/40064/image-upload/ia_1.png?w=800&ssl=1)

# %% [markdown]
# **Основные компоненты:**
#
# - **Карта навигации (структура сайта/приложения):**
#   - Иерархическая структура всех разделов
#   - Связи между разделами
#   - Глубина вложенности (рекомендуется не более 3-4 уровней)
#
# - **Пользовательские пути:**
#   - Последовательность действий для достижения цели
#   - Точки принятия решений
#   - Альтернативные маршруты

# %% [markdown]
# ### **2. Каркасные модели (схематичные прототипы)**

# %% [markdown]
# **Каркасная модель** (англ. wireframe) — это схематичное представление структуры интерфейса без визуального оформления, фокусирующееся на расположении элементов и функциональности.

# %% [markdown]
# ![Текст ссылки](https://visme.co/blog/wp-content/uploads/2022/01/mobile-ui-design-wireframe-example-768x571.jpg)

# %% [markdown]
# **Характеристики каркасных моделей:**
# - Монохромное исполнение (чёрно-белое или оттенки серого)
# - Простые геометрические формы
# - Условные обозначения для контента
# - Акцент на структуре, а не на визуальном стиле

# %% [markdown]
# **Элементы каркасной модели:**
# - Блоки контента (прямоугольники с подписями)
# - Навигационные элементы
# - Формы ввода
# - Кнопки действий
# - Заглушки для изображений

# %% [markdown]
# ### **3. Детальные макеты (визуальные прототипы)**

# %% [markdown]
# **Детальный макет** (англ. mockup) — это высокодетализированный визуальный прототип, максимально приближенный к финальному дизайну продукта.
#
# **Компоненты детального макета:**
# - **Цветовая схема:** основные и вспомогательные цвета
# - **Типографика:** шрифты, размеры, межстрочные интервалы
# - **Сетка:** модульная система расположения элементов
# - **Компоненты интерфейса:** кнопки, поля ввода, карточки
# - **Иконки и иллюстрации**
# - **Реальный контент** (вместо заглушек)

# %% [markdown]
# ![Текст ссылки](https://habrastorage.org/r/w1560/getpro/habr/upload_files/a2e/2e8/af6/a2e2e8af64bdc5a6be9d29ebc35ae13e.jpeg)

# %% [markdown]
# ### **4. Принципы проектирования интерфейсов**

# %% [markdown]
# #### **4.1. Принципы юзабилити Якоба Нильсена**

# %% [markdown]
# 1. **Видимость состояния системы** — пользователь должен понимать, что происходит
# 2. **Соответствие системы реальному миру** — использование понятных терминов
# 3. **Свобода действий** — возможность отмены и повтора
# 4. **Согласованность и стандарты** — единообразие элементов
# 5. **Предотвращение ошибок** — проектирование, минимизирующее ошибки
# 6. **Узнавание вместо вспоминания** — видимость опций и действий
# 7. **Гибкость и эффективность** — ускорители для опытных пользователей
# 8. **Эстетичный и минималистичный дизайн** — отсутствие лишней информации
# 9. **Помощь в распознавании и исправлении ошибок** — понятные сообщения
# 10. **Справка и документация** — доступная помощь при необходимости

# %% [markdown]
# #### **4.2. Законы проектирования интерфейсов**

# %% [markdown]
# **Закон Фиттса:**
# Время достижения цели зависит от расстояния до цели и её размера. Важные элементы должны быть крупными и легкодоступными.
#
# **Закон Хика:**
# Время принятия решения увеличивается с ростом количества альтернатив. Минимизируйте выбор.
#
# **Закон Миллера:**
# Человек может удерживать в краткосрочной памяти 7±2 элемента. Группируйте информацию.
#
# **Принцип Парето:**
# 80% пользователей используют 20% функций. Приоритизируйте основной функционал.

# %% [markdown]
# ### **5. Особенности проектирования различных типов интерфейсов**

# %% [markdown]
# #### **5.1. Графический интерфейс пользователя**

# %% [markdown]
# **Веб-интерфейс:**
# - Адаптивная вёрстка для различных разрешений
# - Кроссбраузерная совместимость
# - Оптимизация загрузки
#
# **Мобильный интерфейс:**
# - Сенсорное управление (размер касания минимум 44×44px для iOS, 48×48dp для Android)
# - Жесты и свайпы
# - Ориентация экрана
#
# **Десктопное приложение:**
# - Многооконный интерфейс
# - Контекстные меню
# - Горячие клавиши

# %% [markdown]
# #### **5.2. Интерфейс командной строки (консольный интерфейс)**

# %% [markdown]
# **Структура команд:**

# %% [markdown]
# ```
# команда [опции] [аргументы]
#
# Пример:
# analyze --input photo.jpg --output result.txt --verbose
# ```

# %% [markdown]
# **Принципы проектирования консольного интерфейса:**
# - Согласованность синтаксиса команд
# - Информативные сообщения об ошибках
# - Подробная справка (--help)
# - Автодополнение команд
# - Цветовое выделение вывода
#
# **Пример структуры вывода:**

# %% [markdown]
# ```
# [ИНФО] Начало анализа изображения...
# [ПРОГРЕСС] ████████░░ 80% | Обработка данных
# [УСПЕХ] ✓ Анализ завершён за 2.3 секунды
# [РЕЗУЛЬТАТ] Обнаружено: Акне (уверенность: 87%)
# ```

# %% [markdown]
# ## **Пример выполненного задания**

# %% [markdown]
# ### **Тема проекта: "Мобильное приложение для анализа состава продуктов питания с использованием технологии оптического распознавания символов"**

# %% [markdown]
# ### **1. ИНФОРМАЦИОННАЯ АРХИТЕКТУРА**

# %% [markdown]
# #### **1.1. Карта навигации (структура системы)**

# %% [markdown]
# ```
# Главный экран
# ├── Найти ингредиент
# │   └── Страница ингредиента
# │       └── Добавить в список
# ├── Анализ состава
# │   ├── Выбор источника
# │   │   ├── Камера
# │   │   └── Галерея
# │   └── Результаты анализа
# │       ├── Вкладка "Анализ" (список ингредиентов)
# │       ├── Вкладка "Текст" (редактирование)
# │       └── Вкладка "Изображение"
# └── Боковое меню
#     ├── Выбор пользователя
#     ├── Настройки пользователя
#     │   ├── Вкладка "Особенности"
#     │   └── Вкладка "Мои ингредиенты"
#     └── Добавить пользователя
# ```

# %% [markdown]
# #### **1.2. Основные пользовательские пути**

# %% [markdown]
# **Сценарий 1: Анализ состава продукта**

# %% [markdown]
# ```
# Главный экран → Кнопка "Анализ состава" → Выбор источника (Камера/Галерея) →
# → Захват/выбор изображения → Обработка изображения → Распознавание текста →
# → Отображение результатов (список ингредиентов с предупреждениями)
#
# ```

# %% [markdown]
# **Сценарий 2: Поиск конкретного ингредиента**

# %% [markdown]
# ```
# Главный экран → Кнопка "Найти ингредиент" → Ввод названия в поиск →
# → Фильтрация списка → Выбор ингредиента → Просмотр информации →
# → Добавление в пользовательский список (опционально)
#
# ```

# %% [markdown]
# **Сценарий 3: Настройка профиля пользователя**

# %% [markdown]
# ```
# Главный экран → Боковое меню → Настройки пользователя →
# → Выбор пищевых привычек → Сохранение изменений
#
# ```

# %% [markdown]
# ### **2. КАРКАСНЫЕ МОДЕЛИ (схематичные прототипы)**

# %% [markdown]
# #### **2.1. Главный экран — каркасная модель**

# %% [markdown]
# ```
# ┌─────────────────────────────────────────────────┐
# │  ≡              Мария                           │
# ├─────────────────────────────────────────────────┤
# │                                                 │
# │            🥗                                   │
# │      Ingredient Analysis                        │
# │                                                 │
# │  ┌───────────────────────────────────────┐      │
# │  │                                       │      │
# │  │        НАЙТИ ИНГРЕДИЕНТ               │      │
# │  │              🔍                       │      │
# │  └───────────────────────────────────────┘      │
# │                                                 │
# │  ┌───────────────────────────────────────┐      │
# │  │                                       │      │
# │  │        АНАЛИЗ СОСТАВА                 │      │
# │  │              📷                       │      │
# │  └───────────────────────────────────────┘      │
# │                                                 │
# └─────────────────────────────────────────────────┘
#
# ```

# %% [markdown]
# **Обоснование структуры:**
# - Минималистичный дизайн с двумя основными действиями соответствует закону Хика
# - Крупные кнопки (высота 120px) обеспечивают удобство нажатия (закон Фиттса)
# - Имя текущего пользователя вверху для быстрой идентификации
# - Иконка меню слева для доступа к дополнительным функциям

# %% [markdown]
# #### **2.2. Схема сценариев использования — каркасная модель**

# %% [markdown]
# Данная схема демонстрирует основные пути навигации пользователя по приложению, показывая связи между различными экранами и возможные переходы между ними. Каждый блок представляет отдельный экран или состояние интерфейса.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### **2.3. Экран поиска ингредиентов — каркасная модель**

# %% [markdown]
# ```
# ┌─────────────────────────────────────────────────┐
# │  ←              Мария                     CO    │
# ├─────────────────────────────────────────────────┤
# │                                                 │
# │  ┌───────────────────────────────────────┐      │
# │  │  🔍  Поиск...                         │      │
# │  └───────────────────────────────────────┘      │
# │                                                 │
# │  ╔═══════════════════════════════════════╗      │
# │  ║ Молоко                           ⚠    ║      │
# │  ╠═══════════════════════════════════════╣      │
# │  ║ Мука пшеничная                        ║      │
# │  ╠═══════════════════════════════════════╣      │
# │  ║ Меланж яичный                    ⚠    ║      │
# │  ╠═══════════════════════════════════╣   ║      │
# │  ║ Масло подсолнечное                    ║      │
# │  ╠═══════════════════════════════════════╣      │
# │  ║ Сахар                                 ║      │
# │  ╚═══════════════════════════════════════╝      │
# │                                                 │
# └─────────────────────────────────────────────────┘
#
# ```

# %% [markdown]
# #### **2.4. Экран результатов анализа — каркасная модель**

# %% [markdown]
# ```
# ┌─────────────────────────────────────────────────┐
# │         АНАЛИЗ          ТЕКСТ       ИЗОБРАЖЕНИЕ │
# ├─────────────────────────────────────────────────┤
# │                                                 │
# │      Найдено 9 ингредиентов                     │
# │                                                 │
# │  ╔═══════════════════════════════════════╗      │
# │  ║ ТВОРОГ                           ⚠    ║      │
# │  ╠═══════════════════════════════════════╣      │
# │  ║ САХАР                            ⚠    ║      │
# │  ╠═══════════════════════════════════════╣      │
# │  ║ КАКАО-МАСЛО                           ║      │
# │  ╠═══════════════════════════════════════╣      │
# │  ║ МОЛОКО                           ⚠    ║      │
# │  ╠═══════════════════════════════════════╣      │
# │  ║ КАКАО ТЁРТОЕ                          ║      │
# │  ╚═══════════════════════════════════════╝      │
# │                                                 │
# └─────────────────────────────────────────────────┘
# ```

# %% [markdown]
# ### **3. ДЕТАЛЬНЫЕ МАКЕТЫ**

# %% [markdown]
# #### **3.1. Главный экран — визуальное решение**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Цветовая схема:**
# - Основной: #8BC34A (светло-зелёный — ассоциация со здоровьем, натуральностью)
# - Вторичный: #FFFFFF (белый — чистота, простота)
# - Акцент: #FFA000 (оранжевый — для предупреждений о проблемных ингредиентах)
# - Текст основной: #212121 (тёмно-серый — хорошая читаемость)
# - Текст вторичный: #757575 (серый — для менее важной информации)
#
# **Типографика:**
# - Название приложения: Roboto Medium, 24sp
# - Заголовки кнопок: Roboto Medium, 18sp, заглавные буквы
# - Основной текст: Roboto Regular, 16sp
# - Подписи: Roboto Light, 14sp
#
# **Обоснование дизайн-решений:**
# - Зелёная цветовая гамма создаёт ассоциацию со здоровым питанием
# - Крупные кнопки с иконками улучшают узнаваемость функций
# - Минимум элементов на экране снижает когнитивную нагрузку
# - Карточный дизайн кнопок с тенью создаёт ощущение глубины

# %% [markdown]
# #### **3.2. Экран поиска ингредиентов и страница ингредиента — детальный макет**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Визуальные решения:**
#
# **Поиск (левая часть):**
# - Поле поиска с иконкой лупы для интуитивности
# - Список с визуальным разделением элементов
# - Предупреждающие иконки (⚠) выделены оранжевым цветом
#
# **Страница ингредиента (правая часть):**
# - Структурированная подача информации
# - Цветовое выделение предупреждений для различных категорий

# %% [markdown]
# #### **3.3. Экран результатов анализа — детальный макет**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Компоненты интерфейса:**
# - Вкладки для переключения между режимами просмотра
# - Счётчик найденных ингредиентов
# - Карточки ингредиентов с предупреждающими иконками
# - Единообразное оформление элементов списка

# %% [markdown]
# #### **3.4. Экран настроек пользователя — детальный макет**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Визуальные решения:**
# - Вкладки для логического разделения настроек
# - Чекбоксы для выбора пищевых привычек
# - Кнопки действий с цветовым кодированием:
#   - Зелёная — сохранение (позитивное действие)
#   - Красная — удаление (деструктивное действие)
# - Диалоговое окно подтверждения удаления для предотвращения ошибок

# %% [markdown]
# #### **3.5. Экран редактирования текста — детальный макет**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Особенности интерфейса:**
# - Текстовое поле с распознанным текстом
# - Кнопка "Сохранить" для применения изменений
# - Возможность корректировки ошибок распознавания
# - Клавиатура с русской раскладкой

# %% [markdown]
# ### **4. АДАПТАЦИЯ ПОД МОБИЛЬНЫЙ ИНТЕРФЕЙС**

# %% [markdown]
# #### **4.1. Принципы мобильного дизайна**

# %% [markdown]
# **Размеры элементов управления:**
# - Минимальный размер кнопки: 48×48dp (Android Material Design)
# - Отступы от краёв экрана: 16dp
# - Межстрочный интервал: 1.5 для основного текста

# %% [markdown]
# **Жесты и взаимодействия:**
# - Свайп между вкладками в результатах анализа
# - Долгое нажатие для дополнительных опций
# - Pull-to-refresh для обновления списков

# %% [markdown]
# #### **4.2. Адаптация под различные размеры экранов**

# %% [markdown]
# Малые экраны (320-360dp):
# - Одноколоночная компоновка
# - Сворачиваемое боковое меню
# - Уменьшенные отступы (8dp)
#
# Средние экраны (360-600dp):
# - Стандартная компоновка
# - Боковое меню выдвижное
# - Стандартные отступы (16dp)
#
# Планшеты (600dp+):
# - Двухколоночная компоновка где возможно
# - Фиксированное боковое меню
# - Увеличенные отступы (24dp)

# %% [markdown]
# ### **5. ИНТЕРАКТИВНЫЙ ПРОТОТИП (опционально)**

# %% [markdown]
# **Примечание:** Для создания полноценного интерактивного прототипа рекомендуется использовать специализированные инструменты:
#
# - **Figma** — создание кликабельного прототипа с переходами между экранами
# - **InVision** — добавление интерактивности к статичным макетам
# - **Adobe XD** — проектирование с анимациями и микровзаимодействиями
# - **Framer** — продвинутое прототипирование с кодом
#
# В данном проекте интерактивный прототип реализован В виде гиф-анимаций.

# %% [markdown]
# На прототипе ниже отображена функция добавления нового пользователя. В этом окне необходимо обязательно ввести имя пользователя, а также можно отметить опции, соответствующие пищевым привычкам данного пользователя при их наличии.

# %% [markdown]
# ![](https://i.yapx.ru/cHfVD.gif)

# %% [markdown]
# На следующем прототипе продемонстрирован пример добавления ингредиента в список «Мои ингредиенты». Для этого нужно поставить галочку в графе «Добавить в список». И при переходе в соответствующую вкладку можно увидеть, что выбранный ингредиент оказался там

# %% [markdown]
# ![](https://i.yapx.ru/cHfWI.gif)

# %% [markdown]
# На последнем прототипе продемонстрирован пример работы приложения, а именно анализ состава продукта питания. При нажатии на кнопку «Анализ состава» предлагается выбрать источник изображения, затем его можно отредактировать. После обработки выводится список найденных в базе данных ингредиентов, можно перейти во вкладку с распознанным текстом, где его можно отредактировать, а также во вкладку с исходным изображением. Во вкладке анализа при нажатии на один из выведенных ингредиентов, в данном случае «соевый лецитин», мы попадаем на страницу с информацией об этом ингредиенте.

# %% [markdown]
# ![](https://i.yapx.ru/cHfZG.gif)

# %% [markdown]
# https://ibb.co/FkR5gKJ1
# https://ibb.co/yBybMpCQ
# https://ibb.co/V4VTtq0

# %% [markdown]
# **Описание интерактивных элементов:**
# - Нажатие на "Найти ингредиент" → плавный переход к экрану поиска
# - Нажатие на "Анализ состава" → модальное окно выбора источника
# - Выбор ингредиента в списке → слайд-переход к странице ингредиента
# - Свайп между вкладками → анимация смены содержимого
# - Нажатие на иконку меню → выезд бокового меню слева

# %% [markdown]
# ### **6. ОБОСНОВАНИЕ ПРОЕКТНЫХ РЕШЕНИЙ**

# %% [markdown]
# #### **6.1. Соответствие принципам юзабилити**

# %% [markdown]
# | Принцип | Реализация в интерфейсе | Пример |
# |---------|-------------------------|--------|
# | Видимость состояния | Отображение имени текущего пользователя, счётчик найденных ингредиентов | "Мария" в заголовке, "Найдено 9 ингредиентов" |
# | Соответствие реальному миру | Использование понятных терминов на русском языке | "Состав", "Ингредиент", а не технические термины |
# | Свобода действий | Возможность редактирования распознанного текста | Вкладка "Текст" с кнопкой "Сохранить" |
# | Согласованность | Единообразные зелёные кнопки, одинаковые списки | Все основные кнопки зелёные прямоугольники |
# | Предотвращение ошибок | Подтверждение удаления пользователя | Диалог "Вы точно хотите удалить аккаунт?" |
# | Узнавание вместо вспоминания | Иконки рядом с текстом, визуальные подсказки | 🔍 для поиска, 📷 для камеры, ⚠ для предупреждений |
# | Минималистичный дизайн | Только необходимые элементы на каждом экране | Главный экран содержит только 2 основные кнопки |

# %% [markdown]
# #### **6.2. Применение законов проектирования**

# %% [markdown]
# **Закон Фиттса:**
# Крупные кнопки "Найти ингредиент" и "Анализ состава" (высота 120px) легко нажимаются большим пальцем при держании телефона одной рукой.
#
# **Закон Хика:**
# На главном экране всего 2 основных действия, что минимизирует время принятия решения пользователем.
#
# **Закон Миллера:**
# Пищевые привычки сгруппированы в один раздел с 5-6 опциями, что не превышает рекомендуемые 7±2 элемента.

# %% [markdown]
# #### **6.3. Улучшения относительно аналогов**

# %% [markdown]
# **Проблема в "Ingred":** Отсутствие поддержки нескольких пользователей
# **Наше решение:** Боковое меню с возможностью добавить до 5 пользователей
#
# **Проблема в "Ingredio":** Платный функционал после 5 сканирований
# **Наше решение:** Полностью бесплатное приложение без ограничений
#
# **Проблема в "Сканер продуктов":** Работа только со штрих-кодами
# **Наше решение:** Распознавание текста состава напрямую с этикетки

# %% [markdown]
# ### **7. СПЕЦИФИКАЦИЯ ИНТЕРФЕЙСА**

# %% [markdown]
# #### **7.1. Сетка и отступы**

# %% [markdown]
# - Базовая сетка: 8dp (density-independent pixels)
# - Отступы от краёв: 16dp
# - Отступы между элементами: 8dp (малые), 16dp (средние), 24dp (большие)
# - Высота панели приложения: 56dp

# %% [markdown]
# #### **7.2. Компоненты интерфейса**

# %% [markdown]
# **Кнопки:**
# - Размер основных кнопок: ширина match_parent - 32dp, высота 48-120dp
# - Скругление углов: 8dp
# - Тень: elevation 4dp
# - Состояния: обычное (зелёный), нажатие (тёмно-зелёный), неактивное (серый)
#
# **Поля ввода:**
# - Высота: 56dp
# - Внутренние отступы: 16dp
# - Скругление: 4dp
# - Подчёркивание при фокусе: 2dp, акцентный цвет
#
# **Списки (RecyclerView):**
# - Высота элемента: 56-72dp
# - Разделители: 1dp, цвет #E0E0E0
# - Отступы внутри элемента: 16dp
#
# **Чекбоксы:**
# - Размер: 24×24dp
# - Отступ от текста: 8dp
# - Цвет активного состояния: зелёный #8BC34A

# %% [markdown]
# #### **7.3. Анимации и переходы**

# %% [markdown]
# - Длительность стандартных анимаций: 300ms
# - Функция плавности: FastOutSlowInInterpolator (Material Design)
# - Переход между экранами: slide (слайд)
# - Появление элементов списка: fade + slide (последовательно)

# %% [markdown]
# ### **8. ЭЛЕМЕНТЫ ГРАФИЧЕСКОГО ИНТЕРФЕЙСА**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Использованные компоненты Android:**
# - **LinearLayout** — линейная разметка для структурирования элементов
# - **ViewPager с табами** — для переключения между вкладками результатов
# - **TextView** — отображение текстовой информации
# - **CheckBox** — выбор пищевых привычек и добавление в список
# - **Button** — кнопки действий
# - **EditText** — редактирование распознанного текста
# - **RecyclerView** — эффективное отображение списков ингредиентов
# - **NavigationDrawer** — выдвижное боковое меню

# %% [markdown]
# ### **9. ДОПОЛНИТЕЛЬНЫЕ ЭКРАНЫ**

# %% [markdown]
# #### **9.1. Экран добавления пользователя**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Особенности:**
# - Поле ввода имени пользователя
# - Чекбоксы для выбора пищевых привычек
# - Кнопка "Сохранить" для подтверждения

# %% [markdown]
# #### **9.2. Боковое меню**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Компоненты:**
# - Список пользователей
# - Кнопка добавления пользователя
# - Настройки текущего пользователя

# %% [markdown]
# ## **ПРИЛОЖЕНИЯ**

# %% [markdown]
# ### **Приложение А. Матрица соответствия требованиям**

# %% [markdown]
# | ID требования | Элемент интерфейса | Экран |
# |---------------|-------------------|--------|
# | ФТ-001 | Кнопка "Анализ состава" | Главный экран |
# | ФТ-002 | Поле поиска | Экран поиска ингредиентов |
# | ФТ-003 | Чекбоксы пищевых привычек | Настройки пользователя |
# | ФТ-004 | Кнопка "Добавить пользователя" | Боковое меню |
# | ФТ-005 | Предупреждающие иконки (⚠) | Списки ингредиентов |
# | ФТ-006 | Вкладка редактирования текста | Результаты анализа |

# %% [markdown]
# ### **Приложение Б. Руководство по стилю**

# %% [markdown]
# **Цветовая палитра:**
# - Primary: #8BC34A
# - Primary Dark: #689F38
# - Accent: #FFA000
# - Background: #FAFAFA
# - Surface: #FFFFFF
# - Error: #F44336
# - Text Primary: #212121
# - Text Secondary: #757575
#
# ---

# %% [markdown]
# ## **Шаблон для заполнения**

# %% [markdown]
# # ПРОТОТИПЫ ПОЛЬЗОВАТЕЛЬСКИХ ИНТЕРФЕЙСОВ

# %% [markdown]
# ## 1. ИНФОРМАЦИОННАЯ АРХИТЕКТУРА

# %% [markdown]
# ### 1.1. Карта навигации (структура системы)

# %%
[Представьте иерархическую структуру разделов вашей системы]

Главное меню
├── Играть по очереди
│   └── Основной UI игры
        └── Панель улучшения главного здания
├── Играть онлайн
│   └── Подсказка о Steam Remote Together и переход в раздел "Играть по очереди"
├── Обучение
├── Настройки
├── Правила
└── О игре

# %% [markdown]
# ### 1.2. Пользовательские пути

# %% [markdown]
# **Сценарий 1: Начало новой игры по очереди**

# %% [markdown]
# Шаг 1: Пользователь на главном экране нажимает "Играть по очереди" > Шаг 2: Переход на экран выбора фракции, где пользователь выбирает фракцию для каждого игрока и нажимает "Играть" > Шаг 3: Переход на экран игры (поле), где отображается остров, моменты фракций и карты в руке > Результат: Игра начата, активный игрок может бросить кубик и выполнять действия.

# %% [markdown]
# **Сценарий 2: Выполнение хода в игре**

# %% [markdown]
# Шаг 1: На экране игры (поле) пользователь нажимает "Бросить кубик" > Шаг 2: Проверка эффектов зданий, отображение попапа эффекта если сработал > Шаг 3: Пользователь выбирает действие, например, использует карту для постройки (нажимает на карту и клетку) или нажимает "Завершить ход" > Результат: Ход завершен, переход к следующему игроку.

# %% [markdown]
# **Сценарий 3: Покупка улучшения базы**

# %% [markdown]
# Шаг 1: Во время хода на экране игры пользователь решает купить улучшение (тратит очки действий) > Шаг 2: Переход на экран выбора улучшения базы, где пользователь выбирает здание из круга > Шаг 3: Просмотр описания и нажатие "Купить (2)" > Результат: Улучшение добавлено к базе, возвращение на экран игры.

# %% [markdown]
# **Сценарий 4: Доступ к настройкам**

# %% [markdown]
# Шаг 1: С главного экрана пользователь нажимает иконку шестеренки > Шаг 2: Переход на экран настроек, где пользователь изменяет опции (например, слайдер яркости или чекбокс VSync) > Шаг 3: Нажатие "Назад" > Результат: Настройки сохранены, возвращение на главный экран.

# %% [markdown]
# **Сценарий 5: Просмотр правил игры**

# %% [markdown]
# Шаг 1: С главного экрана пользователь нажимает иконку свитка или i > Шаг 2: Переход на экран правил с текстом > Шаг 3: Чтение и нажатие "Назад" > Результат: Пользователь ознакомлен с правилами, возвращение на главный экран.

# %% [markdown]
# ## 2. КАРКАСНЫЕ МОДЕЛИ (схематичные прототипы)

# %% [markdown]
# ### 2.1. Главный экран

# %% [markdown]
# +---------------------------------------------------------------------+
# | Diceville                                                           |
# | [Логотип с кубиком]                                                 |
# +-----------------------------------+---------------------------------+
# |                                   | Играть по очереди               |
# |                                   | Играть онлайн                   |
# |                                   | Обучение                        |
# |                                   | Скоро!                          |
# |                                   | Магазин                         |
# |                                   | Выйти                           |
# +-----------------------------------+---------------------------------+
# | [Настройки] [Правила] [Инфо]      | v1.1.9_Demo                     |
# +---------------------------------------------------------------------+
#
# **Описание элементов:**
#
# - Элемент 1: Название (логотип "Diceville" с кубиком в центре сверху).
# - Элемент 2: Кнопка "Играть по очереди" (справа в центре).
# - Элемент 3: Кнопка "Играть онлайн" (справа в центре).
# - Элемент 4: Кнопка "Обучение" (справа в центре).
# - Элемент 5: Кнопка "Скоро!" (справа в центре).
# - Элемент 6: Кнопка "Магазин" (справа в центре).
# - Элемент 7: Кнопка "Выйти" (справа в центре).
# - Элемент 8: Иконка настроек (шестеренка слева внизу).
# - Элемент 9: Иконка правил (свиток слева внизу).
# - Элемент 10: Иконка информации (i слева внизу).
# - Элемент 11: Версия ("v1.1.9_Demo" справа внизу).
#
# **Обоснование структуры:**
# Логотип размещен в центре сверху для привлечения внимания и брендинга, меню кнопок вертикально справа для удобного последовательного чтения и клика в landscape-режиме, где экран шире, что позволяет разместить фон острова слева без перекрытия; иконки опций слева внизу для быстрого доступа к вспомогательным функциям, версия справа внизу для ненавязчивого показа информации; такая структура удобна для пользователя, так как разделяет визуальный фон от интерактивных элементов, минимизируя отвлечения и обеспечивая интуитивную навигацию на широком экране.

# %% [markdown]
# ### 2.2. Экран выбора игроков (фракций)

# %% [markdown]
# +---------------------------------------------------------------------+
# | Выберите вашу фракцию                                               |
# +-----------------------------------+---------------------------------+
# | Игрок1: Пролетариатики [Иконка]   | Игрок3: Подводники [Иконка]     |
# | < i >                             | < i >                           |
# | Удалить                           | Удалить                         |
# +-----------------------------------+---------------------------------+
# | Игрок2: Едуны [Иконка]            | Игрок4: Златодержцы [Иконка]    |
# | < i >                             | < i >                           |
# | Удалить                           | Удалить                         |
# +-----------------------------------+---------------------------------+
# | Назад                             | Играть                          |
# +---------------------------------------------------------------------+
#
#
#
# **Описание элементов:**
#
# - Элемент 1: Заголовок "Выберите вашу фракцию" (сверху в центре).
# - Элемент 2: Кнопка "Играть по очереди" (справа в центре).
# - Элемент 3: Кнопка "Играть онлайн" (справа в центре).
# - Элемент 4: Кнопка "Обучение" (справа в центре).
# - Элемент 5: Кнопка "Скоро!" (справа в центре).
# - Элемент 6: Кнопка "Магазин" (справа в центре).
# - Элемент 7: Кнопка "Выйти" (справа в центре).
# - Элемент 8: Иконка настроек (шестеренка слева внизу).
# - Элемент 9: Иконка правил (свиток слева внизу).
# - Элемент 10: Иконка информации (i слева внизу).
# - Элемент 11: Версия ("v1.1.9_Demo" справа внизу).
#
# **Обоснование структуры:**
# Логотип размещен в центре сверху для привлечения внимания и брендинга, меню кнопок вертикально справа для удобного последовательного чтения и клика в landscape-режиме, где экран шире, что позволяет разместить фон острова слева без перекрытия; иконки опций слева внизу для быстрого доступа к вспомогательным функциям, версия справа внизу для ненавязчивого показа информации; такая структура удобна для пользователя, так как разделяет визуальный фон от интерактивных элементов, минимизируя отвлечения и обеспечивая интуитивную навигацию на широком экране.

# %% [markdown]
# ## 3. ДЕТАЛЬНЫЕ МАКЕТЫ

# %% [markdown]
# ### 3.1. [Название основного экрана]

# %% [markdown]
# [Вставьте изображение детального макета]
#
# **Визуальные решения:**
#
# **Цветовая схема:**
# - Основной цвет: #[HEX] — [обоснование выбора]
# - Вторичный цвет: #[HEX] — [обоснование]
# - Акцентный цвет: #[HEX] — [обоснование]
#
# **Типографика:**
# - Заголовки: [Шрифт, размер]
# - Основной текст: [Шрифт, размер]
# - Подписи: [Шрифт, размер]
#
# **Обоснование дизайна:**
# [Объясните соответствие принципам юзабилити]

# %% [markdown]
# ### 3.2. [Название основного экрана 2]

# %% [markdown]
# [Повторите для 3-5 основных экранов]

# %% [markdown]
# ## 4. ИНТЕРАКТИВНЫЙ ПРОТОТИП (опционально)

# %% [markdown]
# **Ссылка на прототип:** [URL Figma/InVision/другой сервис] или указать, что не реализован
#
# **Описание взаимодействий:**
# - Клик на [элемент] → переход к [экран]
# - Свайп влево → [действие]
# - Долгое нажатие → [действие]

# %% [markdown]
# ## 5. АДАПТАЦИЯ ПОД РАЗЛИЧНЫЕ ИНТЕРФЕЙСЫ

# %% [markdown]
# ### 5.1. Мобильная версия / Консольный интерфейс

# %% [markdown]
# [В зависимости от типа вашей системы]
#
# **Для графических интерфейсов:**
# - Адаптация под экран 320px
# - Адаптация под экран 768px
# - Адаптация под экран 1920px
#
# **Для консольных интерфейсов:**
#
# ```bash

# %% [markdown]
# # Структура основных команд

# %% [markdown]
# command [options] [arguments]

# %% [markdown]
# # Примеры команд

# %% [markdown]
# [команда 1] --help
# [команда 2] --verbose

# %%
**Формат вывода:**

# %% [markdown]
# [Пример структурированного вывода]
# ```

# %% [markdown]
# ## 6. ОБОСНОВАНИЕ ПРОЕКТНЫХ РЕШЕНИЙ

# %% [markdown]
# ### 6.1. Соответствие принципам юзабилити

# %% [markdown]
# | Принцип | Реализация в интерфейсе | Пример |
# |---------|-------------------------|--------|
# | Видимость состояния | [Как реализовано] | [Конкретный элемент] |
# | Соответствие реальному миру | [Как реализовано] | [Конкретный элемент] |
# | Свобода действий | [Как реализовано] | [Конкретный элемент] |

# %% [markdown]
# ### 6.2. Применение законов проектирования

# %% [markdown]
# **Закон Фиттса:**
# [Как учтён в размерах и расположении элементов]
#
# **Закон Хика:**
# [Как минимизировано количество выборов]
#
# **Закон Миллера:**
# [Как сгруппирована информация]

# %% [markdown]
# ### 6.3. Улучшения относительно аналогов

# %% [markdown]
# **Проблема в аналогах:** [Описание проблемы из Задания №7]
# **Наше решение:** [Как эта проблема решена в вашем интерфейсе]
#
# [Приведите 3-5 примеров улучшений]

# %% [markdown]
# ## 7. СПЕЦИФИКАЦИЯ ИНТЕРФЕЙСА

# %% [markdown]
# ### 7.1. Сетка и отступы

# %% [markdown]
# - Базовая сетка: [например, 8px]
# - Колонки: [например, 12 колонок]
# - Отступы: [например, 16px по краям]

# %% [markdown]
# ### 7.2. Компоненты интерфейса

# %% [markdown]
# **Кнопки:**
# - Размер: [ширина × высота]
# - Скругление: [радиус]
# - Состояния: обычное, наведение, нажатие, неактивное
#
# **Поля ввода:**
# - Высота: [px]
# - Отступы: [px]
# - Стили валидации: успех, ошибка, предупреждение

# %% [markdown]
# ### 7.3. Анимации и переходы (если применимо)

# %% [markdown]
# - Длительность: [например, 200-300ms]
# - Функция плавности: [например, ease-in-out]
# - Типы: появление, исчезание, переходы

# %% [markdown]
# ## ПРИЛОЖЕНИЯ

# %% [markdown]
# ### Приложение А. Исходные файлы

# %% [markdown]
# [Ссылки на файлы Figma/Sketch/Adobe XD]

# %% [markdown]
# ### Приложение Б. Руководство по стилю

# %% [markdown]
# [Компоненты интерфейса и правила их использования]

# %% [markdown]
# ### Приложение В. Матрица соответствия требованиям

# %% [markdown]
# | ID требования | Элемент интерфейса | Экран |
# |---------------|-------------------|--------|
# | ФТ-001 | [Элемент] | [Экран] |
# | ФТ-002 | [Элемент] | [Экран] |
#
# ---

# %% [markdown]
# **Связь с дипломной работой:**
#
# Данное задание может быть включено в дипломную работу как:
# - Приложение "Прототипы пользовательских интерфейсов"
# - Раздел практической главы "Проектирование интерфейса системы"
# - Часть раздела "Проектные решения"
#
# **Примечание:** Визуальные прототипы являются важной частью проектной документации и демонстрируют практические навыки проектирования взаимодействия, что особенно ценится в современной индустрии разработки программного обеспечения.

# %% [markdown]
# ## **Требования к выполнению задания**

# %% [markdown]
# 1. **Соответствие предметной области:**
#    - Все прототипы должны отражать специфику вашего проекта
#    - Используйте реальные данные и сценарии из вашей системы
#
# 2. **Полнота охвата:**
#    - Минимум 1-3 каркасных моделей основных экранов
#    - Минимум 3-5 детальных макетов основных экранов
#    - Покрытие основных пользовательских сценариев
#
# 3. **Качество исполнения:**
#    - Каркасные модели должны быть чёткими и понятными
#    - Детальные макеты должны выглядеть профессионально
#    - Соблюдение принципов композиции и визуальной иерархии
#
# 4. **Обоснование решений:**
#    - Каждое проектное решение должно быть аргументировано
#    - Ссылки на принципы юзабилити и законы проектирования
#    - Объяснение улучшений относительно аналогов
#
# 5. **Адаптивность:**
#    - Для веб-интерфейсов: версии для разных устройств
#    - Для мобильных: портретная и ландшафтная ориентации
#    - Для консольных: структура команд и форматы вывода
#
# 6. **Согласованность:**
#    - Единый визуальный стиль во всех макетах
#    - Согласованность с требованиями из Задания №6
#    - Учёт выводов из анализа аналогов (Задание №7)
#
# 7. **Документирование:**
#    - Аннотации к элементам интерфейса
#    - Описание интерактивных элементов
#    - Спецификация цветов, шрифтов, размеров
