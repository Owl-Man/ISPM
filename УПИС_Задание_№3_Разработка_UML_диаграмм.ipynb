# %% [markdown]
# ### **1. Диаграмма вариантов использования**

# %% [markdown]
# ![1. uml use case diagram.png](data:image/png;base64,...)

# %% [markdown]
# ### **2. Диаграмма классов**

# %% [markdown]
# ![2. uml class diagram.png](data:image/png;base64,...)

# %% [markdown]
# ### **3. Диаграмма компонентов**

# %% [markdown]
# ![3. uml component diagram.png](data:image/png;base64,...)

# %% [markdown]
# ### **4. Диаграмма состояний**

# %% [markdown]
# ![4. uml state diagram.png](data:image/png;base64,...)
